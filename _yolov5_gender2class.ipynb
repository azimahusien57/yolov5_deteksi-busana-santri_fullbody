# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
#  %cd  /content/drive/MyDrive/yolov5

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# %pip install -r requirements.txt  # install dependencies

# %%
import torch
from IPython.display import Image, clear_output  # to display images

clear_output()
print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !unzip /content/drive/MyDrive/train_data2.zip
# !curl -L "https://app.roboflow.com/ds/xLE3n125ug?key=TZ1ufMEQQ9" > roboflow.zip; unzip roboflow.zip; rm roboflow.zip

# %%
 # %cd /content/drive/MyDrive/yolov5

# %%
# # Hapus Folder
# !rm -rf /content/drive/MyDrive/yolov5/train_data/label
# # Hapus Folder
# !rm -rf /content/drive/MyDrive/yolov5/train_data

# %%
# %pip install -r requirements.txt  # install dependencies

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
 #%pip install wandb

# %% [markdown]
# # training

# %% [markdown]
# training epoch ketika mendapat kan model maka langkah selanuutnya cuma tinggal mangil di detec.py

# %%
# !python train.py --img 580 --batch 36 --epochs 60 --data /content/drive/MyDrive/clone_yolov5/custom_data2.yaml --weights yolov5s.pt --cache

# %%
# Image(filename='/content/yolov5/runs/train/exp/train_batch0.jpg', width=800)  # train batch 0 mosaics and labels
#Image(filename='/content/yolov5/runs/train/exp2/test_batch1_labels.jpg', width=800)  # test batch 0 labels
#Image(filename='/content/yolov5/runs/train/exp2/test_batch0_pred.jpg', width=800)  # test batch 0 predictions

#NEW Python>=3.6.0 and PyTorch>=1.7.
# # Train/val/test sets as 1) dir: path/to/imgs, 2) file: path/to/imgs.txt, or 3) list: [path/to/imgs1, path/to/imgs2, ..]
# path: ../datasets/coco128  # dataset root dir
# train: images/train2017  # train images (relative to 'path') 128 images
# val: images/train2017  # val images (relative to 'path') 128 images
# test:  # test images (optional)

# %%
Image(filename='/content/yolov5/runs/train/exp2/val_batch0_labels.jpg', width=800)  # test batch 0 labels

# %%
Image(filename='/content/yolov5/runs/train/exp2/val_batch0_pred.jpg', width=800)  # test batch 0 predictions

# %%
# %load_ext tensorboard
# %tensorboard --logdir /content/yolov5/runs/train/exp5

# %% [markdown]
# TAMPILAN HASIL PREDITION

# %%
# !python detect.py --weights /content/yolov5/runs/train/exp//weights/best.pt --img 416 --conf 0.4 --source  /content/yolov5/runs/train/exp/train_batch0.jpg
# !python detect.py --weights /content/drive/MyDrive/clone_yolov5/model_epoch/10_64/best.pt --img 416 --conf 0.4 --source /content/drive/MyDrive/clone_yolov5/ujicoba/uji1.png

# %% [markdown]
# uji coba testing bisa dilihat di coding bawah ini

# %%
Image(filename='/content/yolov5/runs/detect/exp2/uji1.png', width=800)

# %%
#download manual saat dapat model last
from google.colab import files
files.download('/content/yolov5/runs/train/exp5/weights/last.pt')

# %% [markdown]
# untuk menampilkan testing video

# %% [markdown]
# uploud video

# %%
# uploud video secara manual
from google.colab import files
uploaded=files.upload()

# %%
# !python detect.py --weights /content/drive/MyDrive/clone_yolov5/model_epoch/epoch60_36/last.pt --img 416 --conf 0.4 --source /content/drive/MyDrive/clone_yolov5/testing/pos1_a.mp4

# %%
#  %cd /content/drive/MyDrive/custom_yolo/output

# %% [markdown]
# hasil output testing

# %%
from google.colab import files
files. download('/content/yolov5/runs/detect/exp2/pos1_a.mp4')
